# %%
# !ls
# Out:
# data.zip  gts_dataset.py  sample_data

# %%
# !unzip data.zip #Descomprime la carpeta
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  extracting: data/test_prepared/06646.png
#  extracting: data/test_prepared/08013.png
#  extracting: data/test_prepared/05006.png
#  extracting: data/test_prepared/01747.png
#  extracting: data/test_prepared/08006.png
#  extracting: data/test_prepared/03231.png
#  extracting: data/test_prepared/05240.png
#  extracting: data/test_prepared/03732.png
#  extracting: data/test_prepared/09868.png
#  extracting: data/test_prepared/05120.png
#  extracting: data/test_prepared/12523.png
#  extracting: data/test_prepared/10590.png
#  extracting: data/test_prepared/11227.png
#  extracting: data/test_prepared/04026.png
#  extracting: data/test_prepared/06894.png
#  extracting: data/test_prepared/06080.png
#  extracting: data/test_prepared/12147.png
#  extracting: data/test_prepared/07862.png
#  extracting: data/test_prepared/11371.png
#  extracting: data/test_prepared/02423.png
#  extracting: data/test_prepared/09561.png
#  extracting: data/test_prepared/11254.png
#  extracting: data/test_prepared/02490.png
#  extracting: data/test_prepared/01689.png
#  extracting: data/test_prepared/08491.png
#  extracting: data/test_prepared/04401.png
#  extracting: data/test_prepared/10082.png
#  extracting: data/test_prepared/03978.png
#  extracting: data/test_prepared/00992.png
#  extracting: data/test_prepared/06609.png
#  extracting: data/test_prepared/00221.png
#  extracting: data/test_prepared/01346.png
#  extracting: data/test_prepared/01022.png
#  extracting: data/test_prepared/02230.png
#  extracting: data/test_prepared/11904.png
#  extracting: data/test_prepared/09849.png
#  extracting: data/test_prepared/04891.png
#  extracting: data/test_prepared/01822.png
#  extracting: data/test_prepared/10037.png
#  extracting: data/test_prepared/09061.png
#  extracting: data/test_prepared/00701.png
#  extracting: data/test_prepared/00162.png
#  extracting: data/test_prepared/02047.png
#  extracting: data/test_prepared/08581.png
#  extracting: data/test_prepared/04173.png
#  extracting: data/test_prepared/08363.png
#  extracting: data/test_prepared/04218.png
#  extracting: data/test_prepared/08539.png
#  extracting: data/test_prepared/07886.png
#  extracting: data/test_prepared/05692.png
#  extracting: data/test_prepared/03885.png
#  extracting: data/test_prepared/00213.png
#  extracting: data/test_prepared/03777.png
#  extracting: data/test_prepared/06096.png
#  extracting: data/test_prepared/05527.png
#  extracting: data/test_prepared/07950.png
#  extracting: data/test_prepared/06711.png
#  extracting: data/test_prepared/06327.png
#  extracting: data/test_prepared/11824.png
#  extracting: data/test_prepared/08716.png
#  extracting: data/test_prepared/00578.png
#  extracting: data/test_prepared/10452.png
#  extracting: data/test_prepared/05396.png
#  extracting: data/test_prepared/05990.png
#  extracting: data/test_prepared/01910.png
#  extracting: data/test_prepared/00069.png
#  extracting: data/test_prepared/06007.png
#  extracting: data/test_prepared/02798.png
#  extracting: data/test_prepared/02237.png
#  extracting: data/test_prepared/09330.png
#  extracting: data/test_prepared/02401.png
#  extracting: data/test_prepared/08439.png
#  extracting: data/test_prepared/12513.png
#  extracting: data/test_prepared/04419.png
#  extracting: data/test_prepared/04739.png
#  extracting: data/test_prepared/03482.png
#  extracting: data/test_prepared/07196.png
#  extracting: data/test_prepared/01312.png
#  extracting: data/test_prepared/06143.png
#  extracting: data/test_prepared/01138.png
#  extracting: data/test_prepared/04833.png
#  extracting: data/test_prepared/07904.png
#  extracting: data/test_prepared/06737.png
#  extracting: data/test_prepared/06290.png
#  extracting: data/test_prepared/11924.png
#  extracting: data/test_prepared/03923.png
#  extracting: data/test_prepared/02406.png
#  extracting: data/test_prepared/05771.png
#  extracting: data/test_prepared/02243.png
#  extracting: data/test_prepared/03478.png
#  extracting: data/test_prepared/11284.png
#  extracting: data/test_prepared/09059.png
#  extracting: data/test_prepared/00332.png
#  extracting: data/test_prepared/06764.png
#  extracting: data/test_prepared/04550.png
#  extracting: data/test_prepared/06054.png
#  extracting: data/test_prepared/07044.png
#  extracting: data/test_prepared/05114.png
#  extracting: data/test_prepared/01771.png
#  extracting: data/test_prepared/02235.png
#  extracting: data/test_prepared/11114.png
#  extracting: data/test_prepared/00435.png
#  extracting: data/test_prepared/00943.png
#  extracting: data/test_prepared/11182.png
#  extracting: data/test_prepared/11656.png
#  extracting: data/test_prepared/06608.png
#  extracting: data/test_prepared/06541.png
#  extracting: data/test_prepared/11336.png
#  extracting: data/test_prepared/10132.png
#  extracting: data/test_prepared/11535.png
#  extracting: data/test_prepared/01432.png
#  extracting: data/test_prepared/09703.png
#  extracting: data/test_prepared/11109.png
#  extracting: data/test_prepared/05236.png
#  extracting: data/test_prepared/02114.png
#  extracting: data/test_prepared/01659.png
#  extracting: data/test_prepared/04671.png
#  extracting: data/test_prepared/01798.png
#  extracting: data/test_prepared/02266.png
#  extracting: data/test_prepared/07155.png
#  extracting: data/test_prepared/02134.png
#  extracting: data/test_prepared/10008.png
#  extracting: data/test_prepared/10275.png
#  extracting: data/test_prepared/00557.png
#  extracting: data/test_prepared/03187.png
#  extracting: data/test_prepared/09878.png
#  extracting: data/test_prepared/08197.png
#  extracting: data/test_prepared/01912.png
#  extracting: data/test_prepared/00656.png
#  extracting: data/test_prepared/04443.png
#  extracting: data/test_prepared/07350.png
#  extracting: data/test_prepared/08900.png
#  extracting: data/test_prepared/10710.png
#  extracting: data/test_prepared/07601.png
#  extracting: data/test_prepared/00630.png
#  extracting: data/test_prepared/10561.png
#  extracting: data/test_prepared/08880.png
#  extracting: data/test_prepared/05283.png
#  extracting: data/test_prepared/09917.png
#  extracting: data/test_prepared/02005.png
#  extracting: data/test_prepared/07327.png
#  extracting: data/test_prepared/04371.png
#  extracting: data/test_prepared/00719.png
#  extracting: data/test_prepared/12227.png
#  extracting: data/test_prepared/04119.png
#  extracting: data/test_prepared/11935.png
#  extracting: data/test_prepared/05194.png
#  extracting: data/test_prepared/11595.png
#  extracting: data/test_prepared/07442.png
#  extracting: data/test_prepared/08468.png
#  extracting: data/test_prepared/04219.png
#  extracting: data/test_prepared/04271.png
#  extracting: data/test_prepared/06795.png
#  extracting: data/test_prepared/02794.png
#  extracting: data/test_prepared/09992.png
#  extracting: data/test_prepared/00905.png
#  extracting: data/test_prepared/05816.png
#  extracting: data/test_prepared/00143.png
#  extracting: data/test_prepared/08676.png
#  extracting: data/test_prepared/08361.png
#  extracting: data/test_prepared/09814.png
#  extracting: data/test_prepared/11149.png
#  extracting: data/test_prepared/05361.png
#  extracting: data/test_prepared/08597.png
#  extracting: data/test_prepared/05128.png
#  extracting: data/test_prepared/04607.png
#  extracting: data/test_prepared/11148.png
#  extracting: data/test_prepared/09789.png
#  extracting: data/test_prepared/03309.png
#  extracting: data/test_prepared/06986.png
#  extracting: data/test_prepared/09829.png
#  extracting: data/test_prepared/06495.png
#  extracting: data/test_prepared/06105.png
#  extracting: data/test_prepared/02802.png
#  extracting: data/test_prepared/11135.png
#  extracting: data/test_prepared/02069.png
#  extracting: data/test_prepared/09251.png
#  extracting: data/test_prepared/12565.png
#  extracting: data/test_prepared/10739.png
#  extracting: data/test_prepared/07870.png
#  extracting: data/test_prepared/04417.png
#  extracting: data/test_prepared/03260.png
#  extracting: data/test_prepared/02109.png
#  extracting: data/test_prepared/01251.png
#  extracting: data/test_prepared/09478.png
#  extracting: data/test_prepared/02043.png
#  extracting: data/test_prepared/03532.png
#  extracting: data/test_prepared/07235.png
#  extracting: data/test_prepared/00086.png
#  extracting: data/test_prepared/01185.png
#  extracting: data/test_prepared/12618.png
#  extracting: data/test_prepared/07822.png
#  extracting: data/test_prepared/01579.png
#  extracting: data/test_prepared/08686.png
#  extracting: data/test_prepared/10039.png
#  extracting: data/test_prepared/04018.png
#  extracting: data/test_prepared/10658.png
#  extracting: data/test_prepared/11993.png
#  extracting: data/test_prepared/10471.png
#  extracting: data/test_prepared/12180.png
#  extracting: data/test_prepared/04447.png
#  extracting: data/test_prepared/06744.png
#  extracting: data/test_prepared/10687.png
#  extracting: data/test_prepared/01458.png
#  extracting: data/test_prepared/06989.png
#  extracting: data/test_prepared/06893.png
#  extracting: data/test_prepared/08808.png
#  extracting: data/test_prepared/05339.png
#  extracting: data/test_prepared/12158.png
#  extracting: data/test_prepared/00957.png
#  extracting: data/test_prepared/11584.png
#  extracting: data/test_prepared/06487.png
#  extracting: data/test_prepared/08338.png
#  extracting: data/test_prepared/00757.png
#  extracting: data/test_prepared/01639.png
#  extracting: data/test_prepared/11068.png
#  extracting: data/test_prepared/06678.png
#  extracting: data/test_prepared/00225.png
#  extracting: data/test_prepared/00573.png
#  extracting: data/test_prepared/07545.png
#  extracting: data/test_prepared/00685.png
#  extracting: data/test_prepared/01539.png
#  extracting: data/test_prepared/03394.png
#  extracting: data/test_prepared/05986.png
#  extracting: data/test_prepared/00077.png
#  extracting: data/test_prepared/09320.png
#  extracting: data/test_prepared/10454.png
#  extracting: data/test_prepared/00499.png
#  extracting: data/test_prepared/12425.png
#  extracting: data/test_prepared/02316.png
#  extracting: data/test_prepared/08594.png
#  extracting: data/test_prepared/10483.png
#  extracting: data/test_prepared/05656.png
#  extracting: data/test_prepared/07488.png
#  extracting: data/test_prepared/00542.png
#  extracting: data/test_prepared/01832.png
#  extracting: data/test_prepared/04459.png
#  extracting: data/test_prepared/06588.png
#  extracting: data/test_prepared/03899.png
#  extracting: data/test_prepared/01884.png
#  extracting: data/test_prepared/01754.png
#  extracting: data/test_prepared/09423.png
#  extracting: data/test_prepared/03517.png
#  extracting: data/test_prepared/05342.png
#  extracting: data/test_prepared/07564.png
#  extracting: data/test_prepared/00583.png
#  extracting: data/test_prepared/12331.png
#  extracting: data/test_prepared/02077.png
#  extracting: data/test_prepared/09384.png
#  extracting: data/test_prepared/09651.png
#  extracting: data/test_prepared/09441.png
#  extracting: data/test_prepared/10714.png
#  extracting: data/test_prepared/05659.png
#  extracting: data/test_prepared/10919.png
#  extracting: data/test_prepared/10175.png
#  extracting: data/test_prepared/08871.png
#  extracting: data/test_prepared/00477.png
#  extracting: data/test_prepared/07671.png
#  extracting: data/test_prepared/01160.png
#  extracting: data/test_prepared/00534.png
#  extracting: data/test_prepared/01423.png
#  extracting: data/test_prepared/01993.png
#  extracting: data/test_prepared/01396.png
#  extracting: data/test_prepared/02211.png
#  extracting: data/test_prepared/00627.png
#  extracting: data/test_prepared/05606.png
#  extracting: data/test_prepared/04002.png
#  extracting: data/test_prepared/06676.png
#  extracting: data/test_prepared/01838.png
#  extracting: data/test_prepared/03246.png
#  extracting: data/test_prepared/08532.png
#  extracting: data/test_prepared/12392.png
#  extracting: data/test_prepared/11808.png
#  extracting: data/test_prepared/11582.png
#  extracting: data/test_prepared/02110.png
#  extracting: data/test_prepared/05106.png
#  extracting: data/test_prepared/03794.png
#  extracting: data/test_prepared/08002.png
#  extracting: data/test_prepared/09125.png
#  extracting: data/test_prepared/07384.png
#  extracting: data/test_prepared/03384.png
#  extracting: data/test_prepared/07399.png
#  extracting: data/test_prepared/02300.png
#  extracting: data/test_prepared/02106.png
#  extracting: data/test_prepared/04505.png
#  extracting: data/test_prepared/07025.png
#  extracting: data/test_prepared/11142.png
#  extracting: data/test_prepared/04284.png
#  extracting: data/test_prepared/07403.png
#  extracting: data/test_prepared/01962.png
#  extracting: data/test_prepared/03312.png
#  extracting: data/test_prepared/01056.png
#  extracting: data/test_prepared/10737.png
#  extracting: data/test_prepared/11790.png
#  extracting: data/test_prepared/07540.png
#  extracting: data/test_prepared/12064.png
#  extracting: data/test_prepared/01967.png
#  extracting: data/test_prepared/12489.png
#  extracting: data/test_prepared/08369.png
#  extracting: data/test_prepared/02162.png
#  extracting: data/test_prepared/12293.png
#  extracting: data/test_prepared/12286.png
#  extracting: data/test_prepared/08386.png
#  extracting: data/test_prepared/09887.png
#  extracting: data/test_prepared/05938.png
#  extracting: data/test_prepared/00985.png
#  extracting: data/test_prepared/01016.png
#  extracting: data/test_prepared/10932.png
#  extracting: data/test_prepared/06560.png
#  extracting: data/test_prepared/02988.png
#  extracting: data/test_prepared/04304.png
#  extracting: data/test_prepared/06009.png
#  extracting: data/test_prepared/07967.png
#  extracting: data/test_prepared/00135.png
#  extracting: data/test_prepared/00307.png
#  extracting: data/test_prepared/00644.png
#  extracting: data/test_prepared/01784.png
#  extracting: data/test_prepared/03734.png
#  extracting: data/test_prepared/01840.png
#  extracting: data/test_prepared/09430.png
#  extracting: data/test_prepared/09843.png
#  extracting: data/test_prepared/07483.png
#  extracting: data/test_prepared/11855.png
#  extracting: data/test_prepared/01567.png
#  extracting: data/test_prepared/11206.png
#  extracting: data/test_prepared/07669.png
#  extracting: data/test_prepared/04755.png
#  extracting: data/test_prepared/00698.png
#  extracting: data/test_prepared/08885.png
#  extracting: data/test_prepared/03669.png
#  extracting: data/test_prepared/09859.png
#  extracting: data/test_prepared/05978.png
#  extracting: data/test_prepared/03867.png
#  extracting: data/test_prepared/01164.png
#  extracting: data/test_prepared/03831.png
#  extracting: data/test_prepared/11533.png
#  extracting: data/test_prepared/01365.png
#  extracting: data/test_prepared/08061.png
#  extracting: data/test_prepared/04494.png
#  extracting: data/test_prepared/00094.png
#  extracting: data/test_prepared/10601.png
#  extracting: data/test_prepared/11681.png
#  extracting: data/test_prepared/10051.png
#  extracting: data/test_prepared/11934.png
#  extracting: data/test_prepared/12628.png
#  extracting: data/test_prepared/03173.png
#  extracting: data/test_prepared/07425.png
#  extracting: data/test_prepared/09877.png
#  extracting: data/test_prepared/00309.png
#  extracting: data/test_prepared/05313.png
#  extracting: data/test_prepared/02711.png
#  extracting: data/test_prepared/01383.png
#  extracting: data/test_prepared/12610.png
#  extracting: data/test_prepared/05268.png
#  extracting: data/test_prepared/10139.png
#  extracting: data/test_prepared/11262.png
#  extracting: data/test_prepared/10533.png
#  extracting: data/test_prepared/04736.png
#  extracting: data/test_prepared/03738.png
#  extracting: data/test_prepared/06571.png
#  extracting: data/test_prepared/11600.png
#  extracting: data/test_prepared/10857.png
#  extracting: data/test_prepared/12397.png
#  extracting: data/test_prepared/01778.png
#  extracting: data/test_prepared/07247.png
#  extracting: data/test_prepared/02908.png
#  extracting: data/test_prepared/06573.png
#  extracting: data/test_prepared/02307.png
#  extracting: data/test_prepared/07784.png
#  extracting: data/test_prepared/01028.png
#  extracting: data/test_prepared/01182.png
#  extracting: data/test_prepared/05718.png
#  extracting: data/test_prepared/04122.png
#  extracting: data/test_prepared/07267.png
#  extracting: data/test_prepared/10103.png
#  extracting: data/test_prepared/11471.png
#  extracting: data/test_prepared/01296.png
#  extracting: data/test_prepared/04909.png
#  extracting: data/test_prepared/04802.png
#  extracting: data/test_prepared/08086.png
#  extracting: data/test_prepared/04821.png
#  extracting: data/test_prepared/03554.png
#  extracting: data/test_prepared/12075.png
#  extracting: data/test_prepared/01188.png
#  extracting: data/test_prepared/02797.png
#  extracting: data/test_prepared/11395.png
#  extracting: data/test_prepared/10797.png
#  extracting: data/test_prepared/05359.png
#  extracting: data/test_prepared/12059.png
#  extracting: data/test_prepared/11028.png
#  extracting: data/test_prepared/12045.png
#  extracting: data/test_prepared/00448.png
#  extracting: data/test_prepared/01773.png
#  extracting: data/test_prepared/11473.png
#  extracting: data/test_prepared/04361.png
#  extracting: data/test_prepared/10853.png
#  extracting: data/test_prepared/05568.png
#  extracting: data/test_prepared/03504.png
#  extracting: data/test_prepared/11403.png
#  extracting: data/test_prepared/03332.png
#  extracting: data/test_prepared/11969.png
#  extracting: data/test_prepared/01542.png
#  extracting: data/test_prepared/00708.png
#  extracting: data/test_prepared/10525.png
#  extracting: data/test_prepared/06945.png
#  extracting: data/test_prepared/00970.png
#  extracting: data/test_prepared/11377.png
#  extracting: data/test_prepared/02919.png
#  extracting: data/test_prepared/12252.png
#  extracting: data/test_prepared/04527.png
#  extracting: data/test_prepared/02746.png
#  extracting: data/test_prepared/00791.png
#  extracting: data/test_prepared/04560.png
#  extracting: data/test_prepared/05499.png
#  extracting: data/test_prepared/02191.png
#  extracting: data/test_prepared/03601.png
#  extracting: data/test_prepared/06984.png
#  extracting: data/test_prepared/07953.png
#  extracting: data/test_prepared/00037.png
#  extracting: data/test_prepared/10644.png
#  extracting: data/test_prepared/05973.png
#  extracting: data/test_prepared/03916.png
#  extracting: data/test_prepared/01834.png
#  extracting: data/test_prepared/00155.png
#  extracting: data/test_prepared/06293.png
#  extracting: data/test_prepared/06700.png
#  extracting: data/test_prepared/04356.png
#  extracting: data/test_prepared/01184.png
#  extracting: data/test_prepared/02421.png
#  extracting: data/test_prepared/04937.png
#  extracting: data/test_prepared/09838.png
#  extracting: data/test_prepared/05731.png
#  extracting: data/test_prepared/09861.png
#  extracting: data/test_prepared/12518.png
#  extracting: data/test_prepared/04237.png
#  extracting: data/test_prepared/09400.png
#  extracting: data/test_prepared/04865.png
#  extracting: data/test_prepared/02540.png
#  extracting: data/test_prepared/12097.png
#  extracting: data/test_prepared/03444.png
#  extracting: data/test_prepared/05319.png
#  extracting: data/test_prepared/01309.png
#  extracting: data/test_prepared/04974.png
#  extracting: data/test_prepared/05315.png
#  extracting: data/test_prepared/01526.png
#  extracting: data/test_prepared/08124.png
#  extracting: data/test_prepared/10283.png
#  extracting: data/test_prepared/02522.png
#  extracting: data/test_prepared/04120.png
#  extracting: data/test_prepared/07449.png
#  extracting: data/test_prepared/10634.png
#  extracting: data/test_prepared/12511.png
#  extracting: data/test_prepared/10250.png
#  extracting: data/test_prepared/05714.png
#  extracting: data/test_prepared/03814.png
#  extracting: data/test_prepared/10818.png
#  extracting: data/test_prepared/04134.png
#  extracting: data/test_prepared/10428.png
#  extracting: data/test_prepared/02073.png
#  extracting: data/test_prepared/12070.png
#  extracting: data/test_prepared/07761.png
#  extracting: data/test_prepared/04439.png
#  extracting: data/test_prepared/08484.png
#  extracting: data/test_prepared/03442.png
#  extracting: data/test_prepared/04252.png
#  extracting: data/test_prepared/01134.png
#  extracting: data/test_prepared/09795.png
#  extracting: data/test_prepared/08915.png
#  extracting: data/test_prepared/01894.png
#  extracting: data/test_prepared/03658.png
#  extracting: data/test_prepared/12624.png
#  extracting: data/test_prepared/01629.png
#  extracting: data/test_prepared/01541.png
#  extracting: data/test_prepared/06692.png
#  extracting: data/test_prepared/04515.png
#  extracting: data/test_prepared/05290.png
#  extracting: data/test_prepared/08128.png
#  extracting: data/test_prepared/01406.png
#  extracting: data/test_prepared/07152.png
#  extracting: data/test_prepared/01842.png
#  extracting: data/test_prepared/07681.png
#  extracting: data/test_prepared/08189.png
#  extracting: data/test_prepared/02626.png
#  extracting: data/test_prepared/05198.png
#  extracting: data/test_prepared/11606.png
#  extracting: data/test_prepared/03675.png
#  extracting: data/test_prepared/04500.png
#  extracting: data/test_prepared/00762.png
#  extracting: data/test_prepared/09891.png
#  extracting: data/test_prepared/11233.png
#  extracting: data/test_prepared/10617.png
#  extracting: data/test_prepared/04309.png
#  extracting: data/test_prepared/00166.png
#  extracting: data/test_prepared/01524.png
#  extracting: data/test_prepared/12140.png
#  extracting: data/test_prepared/03520.png
#  extracting: data/test_prepared/06430.png
#  extracting: data/test_prepared/01060.png
#  extracting: data/test_prepared/03279.png
#  extracting: data/test_prepared/06930.png
#  extracting: data/test_prepared/08967.png
#  extracting: data/test_prepared/01745.png
#  extracting: data/test_prepared/00887.png
#  extracting: data/test_prepared/02699.png
#  extracting: data/test_prepared/08477.png
#  extracting: data/test_prepared/04661.png
#  extracting: data/test_prepared/04834.png
#  extracting: data/test_prepared/06653.png
#  extracting: data/test_prepared/03895.png
#  extracting: data/test_prepared/11619.png
#  extracting: data/test_prepared/07271.png
#  extracting: data/test_prepared/05368.png
#  extracting: data/test_prepared/09354.png
#  extracting: data/test_prepared/08330.png
#  extracting: data/test_prepared/04971.png
#  extracting: data/test_prepared/04718.png
#  extracting: data/test_prepared/04390.png
#  extracting: data/test_prepared/00480.png
#  extracting: data/test_prepared/05904.png
#  extracting: data/test_prepared/03351.png
#  extracting: data/test_prepared/12251.png
#  extracting: data/test_prepared/12358.png
#  extracting: data/test_prepared/12367.png
#  extracting: data/test_prepared/03992.png
#  extracting: data/test_prepared/09709.png
#  extracting: data/test_prepared/10948.png
#  extracting: data/test_prepared/11749.png
#  extracting: data/test_prepared/08353.png
#  extracting: data/test_prepared/07222.png
#  extracting: data/test_prepared/06699.png
#  extracting: data/test_prepared/08547.png
#  extracting: data/test_prepared/11014.png
#  extracting: data/test_prepared/09938.png
#  extracting: data/test_prepared/06722.png
#  extracting: data/test_prepared/06294.png
#  extracting: data/test_prepared/10131.png
#  extracting: data/test_prepared/04344.png
#  extracting: data/test_prepared/03845.png
#  extracting: data/test_prepared/02149.png
#  extracting: data/test_prepared/07088.png
#  extracting: data/test_prepared/09507.png
#  extracting: data/test_prepared/10159.png
#  extracting: data/test_prepared/01024.png
#  extracting: data/test_prepared/11909.png
#  extracting: data/test_prepared/07340.png
#  extracting: data/test_prepared/02862.png
#  extracting: data/test_prepared/09726.png
#  extracting: data/test_prepared/10767.png
#  extracting: data/test_prepared/04999.png
#  extracting: data/test_prepared/10917.png
#  extracting: data/test_prepared/10826.png
#  extracting: data/test_prepared/02935.png
#  extracting: data/test_prepared/01078.png
#  extracting: data/test_prepared/04484.png
#  extracting: data/test_prepared/02426.png
#  extracting: data/test_prepared/09099.png
#  extracting: data/test_prepared/10096.png
#  extracting: data/test_prepared/10833.png
#  extracting: data/test_prepared/09382.png
#  extracting: data/test_prepared/08722.png
#  extracting: data/test_prepared/12387.png
#  extracting: data/test_prepared/09648.png
#  extracting: data/test_prepared/11694.png
#  extracting: data/test_prepared/12047.png
#  extracting: data/test_prepared/04449.png
#  extracting: data/test_prepared/05219.png
#  extracting: data/test_prepared/06031.png
#  extracting: data/test_prepared/01082.png
#  extracting: data/test_prepared/11958.png
#  extracting: data/test_prepared/03420.png
#  extracting: data/test_prepared/11737.png
#  extracting: data/test_prepared/06621.png
#  extracting: data/test_prepared/10302.png
#  extracting: data/test_prepared/02827.png
#  extracting: data/test_prepared/07224.png
#  extracting: data/test_prepared/03841.png
#  extracting: data/test_prepared/03830.png
#  extracting: data/test_prepared/08508.png
#  extracting: data/test_prepared/07928.png
#  extracting: data/test_prepared/00206.png
#  extracting: data/test_prepared/07383.png
#  extracting: data/test_prepared/04421.png
#  extracting: data/test_prepared/11612.png
#  extracting: data/test_prepared/11989.png
#  extracting: data/test_prepared/04988.png
#  extracting: data/test_prepared/06419.png
#  extracting: data/test_prepared/12578.png
#  extracting: data/test_prepared/10646.png
#  extracting: data/test_prepared/06130.png
#  extracting: data/test_prepared/01673.png
#  extracting: data/test_prepared/11685.png
#  extracting: data/test_prepared/08284.png
#  extracting: data/test_prepared/05288.png
#  extracting: data/test_prepared/07210.png
#  extracting: data/test_prepared/02851.png
#  extracting: data/test_prepared/12514.png
#  extracting: data/test_prepared/06836.png
#  extracting: data/test_prepared/03461.png
#  extracting: data/test_prepared/05765.png
#  extracting: data/test_prepared/00987.png
#  extracting: data/test_prepared/03205.png
#  extracting: data/test_prepared/03700.png
#  extracting: data/test_prepared/06368.png
#  extracting: data/test_prepared/03564.png
#  extracting: data/test_prepared/08053.png
#  extracting: data/test_prepared/11050.png
#  extracting: data/test_prepared/02921.png
#  extracting: data/test_prepared/04029.png
#  extracting: data/test_prepared/05813.png
#  extracting: data/test_prepared/01280.png
#  extracting: data/test_prepared/08823.png
#  extracting: data/test_prepared/00867.png
#  extracting: data/test_prepared/11981.png
#  extracting: data/test_prepared/10645.png
#  extracting: data/test_prepared/03008.png
# ...
#  extracting: data/test_prepared/12598.png
#  extracting: data/test_prepared/10877.png
#  extracting: data/test_prepared/12099.png
#  extracting: data/test_prepared/05644.png
#  extracting: data/test_prepared/04700.png
#  extracting: data/test_prepared/00924.png
#  extracting: data/test_prepared/06888.png
#  extracting: data/test_prepared/04302.png
#  extracting: data/test_prepared/09941.png
#  extracting: data/test_prepared/01728.png
#  extracting: data/test_prepared/09620.png
#  extracting: data/test_prepared/05036.png
#  extracting: data/test_prepared/09798.png
#  extracting: data/test_prepared/09670.png
#  extracting: data/test_prepared/00220.png
#  extracting: data/test_prepared/05920.png
#  extracting: data/test_prepared/05153.png
#  extracting: data/test_prepared/00955.png
#  extracting: data/test_prepared/11305.png
#  extracting: data/test_prepared/03014.png
#  extracting: data/test_prepared/08908.png
#  extracting: data/test_prepared/01766.png
#  extracting: data/test_prepared/10618.png
#  extracting: data/test_prepared/08248.png
#  extracting: data/test_prepared/05870.png
#  extracting: data/test_prepared/01367.png
#  extracting: data/test_prepared/09013.png
#  extracting: data/test_prepared/04001.png
#  extracting: data/test_prepared/07225.png
#  extracting: data/test_prepared/10268.png
#  extracting: data/test_prepared/07812.png
#  extracting: data/test_prepared/06069.png
#  extracting: data/test_prepared/03764.png
#  extracting: data/test_prepared/06299.png
#  extracting: data/test_prepared/11828.png
#  extracting: data/test_prepared/08762.png
#  extracting: data/test_prepared/08088.png
#  extracting: data/test_prepared/02408.png
#  extracting: data/test_prepared/08497.png
#  extracting: data/test_prepared/05578.png
#  extracting: data/test_prepared/08947.png
#  extracting: data/test_prepared/05708.png
#  extracting: data/test_prepared/00824.png
#  extracting: data/test_prepared/11629.png
#  extracting: data/test_prepared/09039.png
#  extracting: data/test_prepared/09550.png
#  extracting: data/test_prepared/12577.png
#  extracting: data/test_prepared/07532.png
#  extracting: data/test_prepared/00441.png
#  extracting: data/test_prepared/09808.png
#  extracting: data/test_prepared/10135.png
#  extracting: data/test_prepared/05125.png
#  extracting: data/test_prepared/04917.png
#  extracting: data/test_prepared/04423.png
#  extracting: data/test_prepared/07445.png
#  extracting: data/test_prepared/03416.png
#  extracting: data/test_prepared/05758.png
#  extracting: data/test_prepared/11205.png
#  extracting: data/test_prepared/06819.png
#  extracting: data/test_prepared/09298.png
#  extracting: data/test_prepared/07533.png
#  extracting: data/test_prepared/10022.png
#  extracting: data/test_prepared/00187.png
#  extracting: data/test_prepared/06782.png
#  extracting: data/test_prepared/10697.png
#  extracting: data/test_prepared/09499.png
#  extracting: data/test_prepared/02550.png
#  extracting: data/test_prepared/01793.png
#  extracting: data/test_prepared/06107.png
#  extracting: data/test_prepared/06709.png
#  extracting: data/test_prepared/03464.png
#  extracting: data/test_prepared/01671.png
#  extracting: data/test_prepared/09923.png
#  extracting: data/test_prepared/00537.png
#  extracting: data/test_prepared/11661.png
#  extracting: data/test_prepared/04966.png
#  extracting: data/test_prepared/00216.png
#  extracting: data/test_prepared/07309.png
#  extracting: data/test_prepared/03945.png
#  extracting: data/test_prepared/01006.png
#  extracting: data/test_prepared/09872.png
#  extracting: data/test_prepared/00807.png
#  extracting: data/test_prepared/12021.png
#  extracting: data/test_prepared/00649.png
#  extracting: data/test_prepared/07300.png
#  extracting: data/test_prepared/04496.png
#  extracting: data/test_prepared/10759.png
#  extracting: data/test_prepared/04460.png
#  extracting: data/test_prepared/10715.png
#  extracting: data/test_prepared/10743.png
#  extracting: data/test_prepared/08523.png
#  extracting: data/test_prepared/08951.png
#  extracting: data/test_prepared/00036.png
#  extracting: data/test_prepared/07139.png
#  extracting: data/test_prepared/05535.png
#  extracting: data/test_prepared/02894.png
#  extracting: data/test_prepared/05230.png
#  extracting: data/test_prepared/04242.png
#  extracting: data/test_prepared/03410.png
#  extracting: data/test_prepared/01099.png
#  extracting: data/test_prepared/07286.png
#  extracting: data/test_prepared/12242.png
#  extracting: data/test_prepared/04036.png
#  extracting: data/test_prepared/11910.png
#  extracting: data/test_prepared/01507.png
#  extracting: data/test_prepared/05868.png
#  extracting: data/test_prepared/03702.png
#  extracting: data/test_prepared/01283.png
#  extracting: data/test_prepared/05580.png
#  extracting: data/test_prepared/12033.png
#  extracting: data/test_prepared/06497.png
#  extracting: data/test_prepared/12590.png
#  extracting: data/test_prepared/09698.png
#  extracting: data/test_prepared/08878.png
#  extracting: data/test_prepared/09533.png
#  extracting: data/test_prepared/07406.png
#  extracting: data/test_prepared/08752.png
#  extracting: data/test_prepared/02967.png
#  extracting: data/test_prepared/00397.png
#  extracting: data/test_prepared/09064.png
#  extracting: data/test_prepared/08913.png
#  extracting: data/test_prepared/02198.png
#  extracting: data/test_prepared/05526.png
#  extracting: data/test_prepared/07438.png
#  extracting: data/test_prepared/12384.png
#  extracting: data/test_prepared/02379.png
#  extracting: data/test_prepared/03526.png
#  extracting: data/test_prepared/06590.png
#  extracting: data/test_prepared/04536.png
#  extracting: data/test_prepared/06490.png
#  extracting: data/test_prepared/06220.png
#  extracting: data/test_prepared/12528.png
#  extracting: data/test_prepared/05305.png
#  extracting: data/test_prepared/11658.png
#  extracting: data/test_prepared/12259.png
#  extracting: data/test_prepared/00504.png
#  extracting: data/test_prepared/10489.png
#  extracting: data/test_prepared/05838.png
#  extracting: data/test_prepared/09871.png
#  extracting: data/test_prepared/07754.png
#  extracting: data/test_prepared/11500.png
#  extracting: data/test_prepared/08781.png
#  extracting: data/test_prepared/11419.png
#  extracting: data/test_prepared/10611.png
#  extracting: data/test_prepared/02213.png
#  extracting: data/test_prepared/00151.png
#  extracting: data/test_prepared/08758.png
#  extracting: data/test_prepared/04596.png
#  extracting: data/test_prepared/07929.png
#  extracting: data/test_prepared/00190.png
#  extracting: data/test_prepared/06597.png
#  extracting: data/test_prepared/02306.png
#  extracting: data/test_prepared/03290.png
#  extracting: data/test_prepared/09848.png
#  extracting: data/test_prepared/08857.png
#  extracting: data/test_prepared/05151.png
#  extracting: data/test_prepared/12058.png
#  extracting: data/test_prepared/11970.png
#  extracting: data/test_prepared/06082.png
#  extracting: data/test_prepared/05328.png
#  extracting: data/test_prepared/03975.png
#  extracting: data/test_prepared/04930.png
#  extracting: data/test_prepared/03339.png
#  extracting: data/test_prepared/04059.png
#  extracting: data/test_prepared/09579.png
#  extracting: data/test_prepared/07263.png
#  extracting: data/test_prepared/08219.png
#  extracting: data/test_prepared/07621.png
#  extracting: data/test_prepared/05612.png
#  extracting: data/test_prepared/05306.png
#  extracting: data/test_prepared/08168.png
#  extracting: data/test_prepared/07536.png
#  extracting: data/test_prepared/00124.png
#  extracting: data/test_prepared/11868.png
#  extracting: data/test_prepared/00070.png
#  extracting: data/test_prepared/11605.png
#  extracting: data/test_prepared/08370.png
#  extracting: data/test_prepared/03479.png
#  extracting: data/test_prepared/11732.png
#  extracting: data/test_prepared/03584.png
#  extracting: data/test_prepared/01431.png
#  extracting: data/test_prepared/01230.png
#  extracting: data/test_prepared/07101.png
#  extracting: data/test_prepared/02611.png
#  extracting: data/test_prepared/07482.png
#  extracting: data/test_prepared/08167.png
#  extracting: data/test_prepared/05622.png
#  extracting: data/test_prepared/10026.png
#  extracting: data/test_prepared/07414.png
#  extracting: data/test_prepared/09724.png
#  extracting: data/test_prepared/01175.png
#  extracting: data/test_prepared/00823.png
#  extracting: data/test_prepared/08072.png
#  extracting: data/test_prepared/01469.png
#  extracting: data/test_prepared/02676.png
#  extracting: data/test_prepared/09960.png
#  extracting: data/test_prepared/01688.png
#  extracting: data/test_prepared/04083.png
#  extracting: data/test_prepared/08909.png
#  extracting: data/test_prepared/02442.png
#  extracting: data/test_prepared/12144.png
#  extracting: data/test_prepared/03406.png
#  extracting: data/test_prepared/10819.png
#  extracting: data/test_prepared/10107.png
#  extracting: data/test_prepared/11376.png

# %% [markdown]
# #  Práctica Obligatoria - Parte I - Dataset
#
# ***<p style="text-align:center;">Aprendizaje Automático II</p>***
# ***<p style="text-align:center;">German Traffic Signs</p>***
#
# En este Notebook se resumen las características del *dataset* a utilizar a lo largo de la práctica.
#
# ### German Traffic Sign (GTS)
#
# El **German Traffic Sign** es un dataset ampliamente utilizado en tareas de clasificación y reconocimiento de señales de tráfico.
#
# ---
#
# #### **Características del Dataset**
# - **Cantidad de clases:** 43 clases de señales de tráfico, que incluyen límites de velocidad, prohibiciones, advertencias y otros tipos de señales.
# - **Número de imágenes:** Alrededor de 50,000 imágenes para entrenamiento y validación, y aproximadamente 12,000 imágenes para prueba.
# - **Dimensiones de las imágenes:** Resoluciones variables, típicamente entre 15x15 y 250x250 píxeles.
# - **Formato de los datos:**
#   - Cada imagen viene etiquetada con su clase correspondiente.
#   - Metadatos como tamaño de la imagen, coordenadas del ROI (Región de Interés) y nombre de archivo están disponibles en archivos CSV.
#
# ---
#
# #### **Licencia**
# El dataset es de uso libre para fines educativos y de investigación.
#
# Más información está disponible en el sitio oficial del benchmark: [GTSRB Dataset](http://benchmark.ini.rub.de/).
#
# ---
#
# #### **Práctica**
#
# En el contexto de esta práctica, se proporciona una adaptación de dicho conjunto de datos.
#
# En particular, se proporcionan los datasets (`Dataset`) de PyTorch para trabajar con ellos.
#
# ### Evaluación - 1.5/10 puntos
#
# Puntuación de cada parte sobre el total de la práctica:
# - **[Ejercicio 1]** 0.5 puntos.
# - **[Ejercicio 2]** 1 punto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader
from torchvision import transforms

from gts_dataset import GTS

# %% [markdown]
# El conjunto de datos a utilizar será dividido en 3 partes:

# %%
# Definir las transformaciones y conversión a tensor
transform = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = GTS(csv_file='train.csv', root_dir='./data', transform=transform)
valid_dataset = GTS(csv_file='valid.csv', root_dir='./data', transform=transform)
test_dataset = GTS(csv_file='test.csv', root_dir='./data', transform=transform)

# %% [markdown]
# Es decir, deberás utilizar siempre los conjuntos:
# * `train_dataset`
# * `valid_dataset`
# * `test_dataset`

# %% [markdown]
# Dados estos tres conjuntos:
# 1. Cuenta cuántos ejemplos hay en cada uno.
# 2. Comprueba que, efectivamente, existen 43 clases.
# 3. Comprueba que las dimensiones de las imágenes son: 25x25x3.
# 4. Crea una función `visualize_subset(dataset, num_images)` que visualice un número dado de imágenes.

# %% [markdown]
# **[Ejercicio 1]**

# %%
train_dataset.data
# Out:
#                            Path  ClassId
# 0      train_prepared/34356.png       35
# 1      train_prepared/27880.png       23
# 2      train_prepared/09131.png        5
# 3      train_prepared/13162.png        8
# 4      train_prepared/28286.png       24
# ...                         ...      ...
# 19599  train_prepared/06265.png        3
# 19600  train_prepared/11284.png        7
# 19601  train_prepared/38158.png       39
# 19602  train_prepared/00860.png        1
# 19603  train_prepared/15795.png       10
#
# [19604 rows x 2 columns]

# %%
image, id = train_dataset[0]
image.shape

# %%
##################### COMPLETAR #######################
# 1.
# Número de ejemplos en los conjuntos de entrenamiento y validación
num_train = len(train_dataset)
num_valid = len(valid_dataset)
num_test = len(test_dataset)

print("----------------------------------------------------------")
print(f"Número de ejemplos en el conjunto de entrenamiento: {num_train}")
print(f"Número de ejemplos en el conjunto de validación: {num_valid}")
print(f"Número de ejemplos en el conjunto de test: {num_test}")


##################### COMPLETAR #######################
# 2.
n_clases= len(set(train_dataset.data['ClassId']))
print(f"Número de clases en el dataset: {n_clases}")

##################### COMPLETAR #######################
# 3.
# Obtener una imagen del dataset
image, id = train_dataset[0]
channels, height, weight = image.shape

print(f"Tamaño de las imágenes: {height}x{weight}")
print("----------------------------------------------------------")

##################### COMPLETAR #######################
4.
# Visualizar algunos ejemplos
def visualize_subset(dataset, num_images=6):
    """
    Visualiza ejemplos directamente de un Subset o Dataset.

    :param dataset: Dataset o Subset que contiene las imágenes y etiquetas.
    :param num_images: Número de imágenes a mostrar.
    """
    indices = np.arange(num_images)
    images = []
    labels = []

    for idx in indices:
        image, label = dataset[idx]
        images.append(image)
        labels.append(label)

    images =  torch.stack(images)    # Convertir la lista de imágenes en un tensor
    images =   images.permute(0, 2, 3, 1)     # Permutar dimensiones para visualizar (batch, h, w, c)


    # Mostrar imágenes
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))
    for idx in range(num_images):
        axes[idx].imshow(images[idx])
        axes[idx].set_title(f"Clase: {labels[idx]}")
        axes[idx].axis('off')
    plt.tight_layout()
    plt.show()


# Visualizar ejemplos del conjunto de entrenamiento
visualize_subset(train_dataset)
# Out:
# ----------------------------------------------------------
# Número de ejemplos en el conjunto de entrenamiento: 19604
# Número de ejemplos en el conjunto de validación: 19605
# Número de ejemplos en el conjunto de test: 12630
# Número de clases en el dataset: 43
# Tamaño de las imágenes: 25x25
# ----------------------------------------------------------

# %% [markdown]
# Ahora que tienes acceso a los datos, crea un histograma de las clases para comprobar si están o no desbalanceadas:

# %%
##################### COMPLETAR #######################
# Crear un histograma

def plot_class_distribution(dataset):
    """
    Muestra un histograma de las clases en el dataset.

    :param dataset: Dataset o Subset que contiene las imágenes y etiquetas.
    """
    # Obtener todas las etiquetas del dataset
    labels = [dataset[idx][1] for idx in range(len(dataset))]

    # Crear el histograma
    plt.figure(figsize=(12, 6))
    sns.histplot(labels, bins=len(set(labels)), kde=False, color='blue')
    plt.title("Distribución de Clases en el Dataset")
    plt.xlabel("Clases")
    plt.ylabel("Número de Ejemplos")
    plt.xticks(range(len(set(labels))))
    plt.show()


# Mostrar el gráfico
plot_class_distribution(train_dataset)
################### Fin COMPLETAR #####################

# %% [markdown]
# Como puedes comprobar, las clases de este dataset están fuertemente desbalanceadas. Para paliar este posible problema, puedes crear un `sampler` específico y usarlo en el `dataloader`.
#
# Ayúdate de la documentación de `WeightedRandomSampler`, para obtener un `dataloader` de manera que las clases tengan la misma probabilidad de ser muestreadas.

# %% [markdown]
# **[Ejercicio 2]**

# %%
from torch.utils.data import WeightedRandomSampler

##################### COMPLETAR #######################
batch_size = 16

# Paso 1: Calcular el histograma (frecuencias por clase)

labels = [train_dataset[idx][1] for idx in range(len(train_dataset))]
labels_tensor= torch.tensor(labels)
histograma= torch.histc(labels_tensor.float(), bins=len(set(labels_tensor)), min=labels_tensor.min(), max=labels_tensor.max())
class_counts = torch.bincount(labels_tensor)


# Paso 2: Asignar pesos inversamente proporcionales a las frecuencias
max_count = class_counts.max().float()
class_weights = max_count / (class_counts.float() )


# Paso 3: Asignar pesos a cada ejemplo del dataset
sample_weights = class_weights[labels_tensor]

# Paso 4: Crear el WeightedRandomSampler
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(train_dataset), replacement=True)

# Paso 5: Crear el DataLoader con el sampler
train_dataloader_uniform = DataLoader(train_dataset, batch_size=batch_size, sampler=sampler)

################### Fin COMPLETAR #####################
# Crear un contador para las clases sampleadas
sampled_labels = []

# Samplear las etiquetas usando el sampler
for data_batch, label_batch in train_dataloader_uniform:
    sampled_labels.extend(label_batch.numpy())

# Convertir las etiquetas sampleadas a un tensor y calcular el histograma
sampled_labels = torch.tensor(sampled_labels)
sampled_histogram = torch.bincount(sampled_labels)

plt.figure(figsize=(10, 6))
sns.barplot(x=list(range(len(sampled_histogram))), y=sampled_histogram.numpy(), color='blue')

# Personalización del gráfico
plt.title('Distribución de clases en el conjunto de entrenamiento muestreado uniformemente', fontsize=16)
plt.xlabel('Clase (ClassId)', fontsize=14)
plt.ylabel('Número de ejemplos', fontsize=14)
plt.xticks(ticks=range(len(sampled_histogram)), rotation=90)  # Mostrar todas las clases en el eje x
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
